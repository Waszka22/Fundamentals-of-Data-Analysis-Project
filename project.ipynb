# %% [markdown]
# ### Fundamentals Of Data Analysis
# ###  Project
# #### Autror: **Agnieszka Waszczuk**
#
# This repository is used for the project given by the lecture on
# Fundamentals of Data Analaysis module on <em><strong>Higher Diploma in Science in Computing in Data Analytics at ATU</strong></em>.
#
# The module presents:
# * Source and investigate sets of data
# * Programmatically explore and visualise data
# * Apply basic mathematical data analysis techniques to data sets
# * Write programs to automate basic data analysis techniques
#
# ***
#
# ### Problem Statement:
#
# * The project is to create a notebook investigating the variables and
# data points within the well-known iris flower data set associated
# with Ronald A Fisher.
# * In the notebook, you should discuss the classification of each
# variable within the data set according to common variable types
# and scales of measurement in mathematics, statistics, and Python.
# * Select, demonstrate, and explain the most appropriate summary
# statistics to describe each variable.
# * Select, demonstrate, and explain the most appropriate plot(s) for
# each variable.
# * The notebook should follow a cohesive narrative about the data
# set.
#
# ***
#
# ### About dataset:
#
# The Data was extracted from <em><strong>Fisher's Irish data set</strong></em>.  The Famous database from Fisher, 1936. The data set consists of 50 sampels of three Iris species: Iris-setosa, Iris-versicolor and Iris-virginica. The Iris flower data set or Fisher's Iris data set is a multivariate data set used and made famous by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis [1].

# %% [markdown]
# ![Alt text](flowers.png)

# %% [markdown]
# ### Table of content
#
# 1. Introduction to notebook
#
# 2.  Describe dataset ussing descriptive statiscic and plot
#    + Reading dataset
#    + Summary Statistics
#    + Data Visualization
# 3. Exploring Data Relationships
# 4. Conclusion

# %% [markdown]
# Description about database
# * The Iris Data set has 150 rows and 5 colums.
# * The data has two dimension.
# * No missing data in this dataset.
# * The first column represented sepal length, the second column represented sepal width, the third column represented petal length, and the fourth column represented petal width.
# * The data was imported from csv file.

# %% [markdown]
# Reading in the CSV file

# %% [markdown]
# Pandas is a widely-used Python library for data science, analysis, and machine learning that offers a flexible and intuitive way to handle data sets of all sizes. One of the most important functionalities of pandas is the tools it provides for reading and writing data. For data available in a tabular format and stored as a CSV file, you can use pandas to read it into memory using the <code>read_csv()</code> function, which returns a pandas dataframe [2].

# %%
# read the dataset
iris_data = pd.read_csv('iris.data',header=None)
print(iris_data)

# name all columns
column_names=['sepal length in cm','sepal width in cm','petal length in cm','petal width in cm','class']
iris_data.columns = column_names
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Importing Libraries

# %%
# import libries
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Variable Type

# %% [markdown]
# Exploring Dataset

# %%
# printing data types
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1   sepal width in cm   150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3   petal width in cm   150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#printing size of dataset 
iris_data.shape
# Out:
# (150, 5)

# %%
# printing top 10 observation
iris_data.head(10)
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
# 5                 5.4                3.9                 1.7
# 6                 4.6                3.4                 1.4
# 7                 5.0                3.4                 1.5
# 8                 4.4                2.9                 1.4
# 9                 4.9                3.1                 1.5
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa
# 5                0.4  Iris-setosa
# 6                0.3  Iris-setosa
# ...

# %%
# printing last 10 observation 
iris_data.tail(10)
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 140                 6.7                3.1                 5.6
# 141                 6.9                3.1                 5.1
# 142                 5.8                2.7                 5.1
# 143                 6.8                3.2                 5.9
# 144                 6.7                3.3                 5.7
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 140                2.4  Iris-virginica
# 141                2.3  Iris-virginica
# 142                1.9  Iris-virginica
# 143                2.3  Iris-virginica
# 144                2.5  Iris-virginica
# ...

# %%
# checking missing values
iris_data.isnull().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %% [markdown]
# The Iris dataset has no missing values

# %% [markdown]
# #####  Data types in pandas[3]:
# * Numeric: This includes integers and floating-point numbers. Numeric data is typically used for quantitative analysis and mathematical operations.
# * String: This data type is used to represent textual data such as names, addresses, and descriptions.
# * Boolean: This data type can only have two possible values: True or False. Boolean data is often used for logical operations and filtering.
# * Categorical: This data type represents data that takes on a limited number of values. Categorical data is often used for grouping and aggregating data.
# * Object: This data type is a catch-all for data that does not fit into the other categories. It can include a variety of different data types, such as lists, dictionaries, and other objects.
# * Datetime: This data type is used to represent dates and times. pandas has powerful tools for manipulating datetime data.

# %%
# checking data type
iris_data.dtypes
# Out:
# sepal length in cm    float64
# sepal width in cm     float64
# petal length in cm    float64
# petal width in cm     float64
# class                  object
# dtype: object

# %% [markdown]
# #### The Iris dataset represents:
#
# String Data Type:
#
# * Corresponds to the class (setosa, versicolor, virginica).
#
# Float Data Type:
#
# * Corresponds to measurements like sepal length, sepal width, petal length, and petal width.

# %% [markdown]
# ##### Main types of data statiscic[2]:
#
# &rarr;Categorical Data
#
# * Nominal data
#
# * Ordinal data
#
# &rarr;Numerical Data
#
# * Discrete data
#
# * Continuous data
#
# ##### The Irish dataset inclueds the following types of variables:
#
# Numeric Variables:
#
# * Petal Length- Continuous numerical variable
# * Petal Width- Continuous numerical variable
# * Sepal Length- Continuous numerical variable
# * Sepal Width- Continuous numerical variable
#
#
# Categorical Variables:
#
# * Species- Nominal Categorical Variable

# %% [markdown]
# #### Summary Statistics

# %% [markdown]
# The graet metod to explore statiscic summary of Irish dataset is describele() function. This function produces for each columne some statisctic data such a mean, median, std, max, min, quartiles.
#
# Statiscic Summary: The metod <code>describe()</code>in Python returns numerical data for each column [5]:
#
# * count: the number of not-empty values
# * mean: the average value
# * std: the standard deviation
# * min: the minimum value
# * 25% :the 25% percentile
# * 50% :the 50% percentile
# * 75% :the 75% percentile
# * max : the maximum value

# %%
# printing summary of dataset
iris_data.describe()
# Out:
#        sepal length in cm  sepal width in cm  petal length in cm  \
# count          150.000000         150.000000          150.000000
# mean             5.843333           3.054000            3.758667
# std              0.828066           0.433594            1.764420
# min              4.300000           2.000000            1.000000
# 25%              5.100000           2.800000            1.600000
# 50%              5.800000           3.000000            4.350000
# 75%              6.400000           3.300000            5.100000
# max              7.900000           4.400000            6.900000
#
#        petal width in cm
# count         150.000000
# mean            1.198667
# std             0.763161
# min             0.100000
# 25%             0.300000
# 50%             1.300000
# 75%             1.800000
# max             2.500000

# %% [markdown]
# #### Summary statistics for each numerical variable

# %%
# prepare variables
sepal_len = iris_data['sepal length in cm']
sepal_wid = iris_data['sepal width in cm']
petal_len = iris_data['petal length in cm']
petal_wid = iris_data['petal width in cm']
classes = iris_data['class']

# %%
variable_names = {'sepal_len':sepal_len,'sepal_wid':sepal_wid,'petal_wid':petal_wid,'petal_len':petal_len,'classes':classes}
for key,value in variable_names.items():
  f = open(f'{key}.txt', 'w')
  f.writelines([str(value)])
  f.close()

# %% [markdown]
# ##### Summary statistics for Peta Width

# %%
# display summary statistics for Peta Width
print("Summary Statistics for Petal Width :")
print(petal_wid.describe())
# Out:
# Summary Statistics for Petal Width :
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal width in cm, dtype: float64

# %% [markdown]
# * count: the total number of data points for the petal width variable  is 150
#
# * mean: the average is approximately 1.20
#
# * std: the standard deviation, a measure of the amount of variation or dispersion in the petal widths is approximately 0.76
#
# * min: the minimum petal width in the dataset is 0.1
#
# * 25% (1st Quartile): the value below which 25% of the petal widths is 0.3
#
# * 50% (2nd Quartile/Median): the median or middle value of the petal widths is 1.3
#
# * 75% (3rd Quartile): the value below which 75% of the petal widths fall, which is 1.8
#
# * max: the maximum petal width in the dataset, which is 2.5

# %% [markdown]
# ##### Summary statistics for Petal Length

# %%
# display summary statistics for Petal Length
print("Summary Statistics for Petal Length :")
print(petal_len.describe())
# Out:
# Summary Statistics for Petal Length :
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal length in cm, dtype: float64

# %% [markdown]
# * count: the total number of data points for the petal length is 150
#
# * mean: the average or mean of the petal lengths is approximately 3.76
#
# * std: the standard deviation is approximately 1.76
#
# * min: the minimum is 1.0
#
# * 25% (1st Quartile): the value below which 25% of the petal lengths fall is 1.6
#
# * 50% (2nd Quartile/Median): The median or middle value of the petal lengths is 4.35
#
# * 75% (3rd Quartile): The value below which 75% of the petal lengths is 5.1
#
# * max: the maximum is 6.9

# %% [markdown]
# ##### Summary statistics for Sepal Width

# %%
# display summary statistics for Sepal Width
print("Summary Statistics for Sepal Lengt Width :")
print(sepal_wid.describe())
# Out:
# Summary Statistics for Sepal Lengt Width :
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal width in cm, dtype: float64

# %% [markdown]
# * count: the total number of data points for the sepal width is 150
#
# * mean: the mean of the sepal widths is approximately 3.05
#
# * std: a measure of the amount sepal width is approximately 0.43
#
# * min: the minimum sepal width in the dataset, which is 2.0
#
# * 25% (1st Quartile): The value below which 25% of the sepal width is 2.8
#
# * 50% (2nd Quartile/Median): the median or middle value of the sepal width, which is 3.0
#
# * 75% (3rd Quartile): The value below which 75% of the sepal width is 3.3
#
# * max: the maximum is 4.4

# %% [markdown]
# ##### Summary statistics for Sepal Lenghts

# %%
# display summary statistics for Sepal Lenghts
print("Summary Statistics for Sepal Length:")
print(sepal_len.describe())
# Out:
# Summary Statistics for Sepal Length:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal length in cm, dtype: float64

# %% [markdown]
# * count: the total number of data points for the sepal length variable is 150
#
# * mean: the average of the sepal lengths is 5.84
#
# * std: the standard deviation is approximately 0.83
#
# * min: the minimum sepal length in the dataset is 4.3
#
# * 25% (1st Quartile): the value below which 25% of the sepal lengths is 5.1
#
# * 50% (2nd Quartile/Median): the median or middle value of the sepal lengths is 5.8
#
# * 75% (3rd Quartile): the value below which 75% of the sepal lengths is 6.4
#
# * max: the maximum sepal is 7.9

# %% [markdown]
# # Data Visualization

# %% [markdown]
# We can use various of data visualization modules to presents data, using Python libraries. In this project we use:
#
# * Matplotlib
# * Seaborn
#
# To plot the histagram, we import libraries from Matplotlib. Mataplotlib is a powerful data visualization suite. For each variable, we plot a histagram showing the distribution of the iris dataset. Histagrams are ideal for showing whether a distribution is symmetrical or left/right skewed.

# %% [markdown]
# Types Iris Flower in the Iris Dataset
#
# * Iris-setosa
# * Iris-virginica
# * Iris-versicolor

# %%
# import matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
# Code taken from:-https://seaborn.pydata.org/generated/seaborn.countplot.html

# countplot for the class 
plt.figure(figsize=(8, 5))
sns.countplot(data=iris_data, x='class', palette='cool')
plt.title('Countplot of Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=petal_wid, bins='auto', color='#98F5FF',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
# add a lable for plot
plt.xlabel('Value')
plt.ylabel('Frequency')
#add grid
plt.grid(True)
# add a title for plot
plt.title('Histagram of Petal Width in cm')
# Out:
# Text(0.5, 1.0, 'Histagram of Petal Width in cm')

# %% [markdown]
#  Histagram of Pental Lenght

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=petal_len, bins='auto', color='#FFD900',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
# add a title for plot and lables
plt.xlabel('Value')
plt.ylabel('Frequency')
#add grid
plt.grid(True)
# add title
plt.title('Histagram of Petal Length in cm')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
#  Histagram of Sepal Lenght

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=sepal_len, bins='auto', color='#BF3EFF',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
# add a lable for plot
plt.xlabel('Value')
plt.ylabel('Frequency')
# add a title for plot
plt.title('Histagram of Sepal Length in cm')
# Out:
# Text(0.5, 1.0, 'Histagram of Sepal Length in cm')

# %% [markdown]
#  Histagram of Sepal Width

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=sepal_wid, bins='auto', color='#66CD00', alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
# add a lable for plot
plt.xlabel('Value')
plt.ylabel('Frequency')
# add a title for plot
plt.title('Histagram of Sepal Width in cm')
# Out:
# Text(0.5, 1.0, 'Histagram of Sepal Width in cm')

# %% [markdown]
# Analyzing Distrubution for the each numerical variables

# %%
# plot histograms for numerical variables 
for variable in numeric_variables:
    plt.figure(figsize=(8, 5))

    # plot histogram
    n, bins, patches = plt.hist(x=iris_data[variable], bins='auto', color ='#BF3EFF', alpha=0.7, rwidth=0.85)
    plt.grid(axis='y', alpha=0.75)

    # add vertical line at the mean value
    mean_value = iris_data[variable].mean()
    plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_value:.2f}')

    # calculate skewness
    skewness = iris_data[variable].skew()

    # sdd line and text to indicate skewness
    if skewness > 0:
        plt.axvline(mean_value + 2 * iris_data[variable].std(), color='blue', linestyle='dashed', linewidth=2, label='Right Skew')
        plt.text(mean_value + 2 * iris_data[variable].std(), max(n) * 0.8, f'Skewness: {skewness:.2f}', color='orange')
    else:
        plt.axvline(mean_value - 2 * iris_data[variable].std(), color='blue', linestyle='dashed', linewidth=2, label='Left Skew')
        plt.text(mean_value - 2 * iris_data[variable].std(), max(n) * 0.8, f'Skewness: {skewness:.2f}', color='orange')

    # sdd labels and title
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {variable}')
    # add legend
    plt.legend()

# %% [markdown]
#  ## Exploring Data Relationships

# %% [markdown]
# Exploring relation between sepal lenght, sepal width, peta lenght, petal width
#
# Correlation Pearson's

# %%
# data creation for all class
iris_data.corr(method="pearson")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18876\548499490.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.corr(method="pearson")
#                     sepal length in cm  sepal width in cm  petal length in cm  \
# sepal length in cm            1.000000          -0.109369            0.871754
# sepal width in cm            -0.109369           1.000000           -0.420516
# petal length in cm            0.871754          -0.420516            1.000000
# petal width in cm             0.817954          -0.356544            0.962757
#
#                     petal width in cm
# sepal length in cm           0.817954
# sepal width in cm           -0.356544
# petal length in cm           0.962757
# petal width in cm            1.000000

# %% [markdown]
# Correlation in a separate data frame

# %%
r= np.corrcoef(petal_len,sepal_len)
r
# Out:
# array([[1.        , 0.87175416],
#        [0.87175416, 1.        ]])

# %%
r= np.corrcoef(petal_len,petal_wid)
r
# Out:
# array([[1.       , 0.9627571],
#        [0.9627571, 1.       ]])

# %% [markdown]
# Interpretation
# * strong  positive correlation between Petal Width and Petal Length (0.96)
# * strongg positive correlation between Petal Length and Sepal Length (0.87)

# %%
# add pairplot of iris_dataset

sns.pairplot(iris_data, hue= 'class')

# %% [markdown]
# The heatmap is a data visualization technique that is used to analyze the dataset as colors in two dimensions. Basically, it shows a correlation between all numerical variables in the dataset. In simpler terms, we can plot the above-found correlation using the heatmaps[4].

# %%
##Adapted from code from https://seaborn.pydata.org/generated/seaborn.heatmap.html
# Create a Pearson correlation matrix
correlation_matrix = iris_data.corr(method='pearson', numeric_only=True)

# plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
 
plt.show()

# %%
# create scatter plot 
colors = np.arange(150)
plt.scatter(sepal_len, sepal_wid,c=colors, cmap='viridis')
plt.colorbar()
plt.title('scatter plot')
# display a scatter
plt.show()

# %% [markdown]
# Reference:
#
# [1]: *Wikimedia Foundation Inc*, https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# [2]: *DataCamp*, https://www.datacamp.com/tutorial/pandas-read-csv
#
# [3]: *DataCamp*, https://www.datacamp.com/tutorial/categorical-data
#
# [4]: *Heatmaps*, https://www.geeksforgeeks.org/exploratory-data-analysis-on-iris-dataset/
#
# [5]: *W3Schools*, Pandas DataFrame, https://www.w3schools.com/python/pandas/ref_df_describe.asp
#
# Additiona Reading:
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
# https://www.practicalpythonfordatascience.com/ap_seaborn_palette

# %% [markdown]
# ***
# #### End
