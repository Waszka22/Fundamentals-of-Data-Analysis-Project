# %% [markdown]
# ### Fundamentals Of Data Analysis
# ###  Tasks
# #### Autror: **Agnieszka Waszczuk**
#
#
# This repository is used for the tasks given by the lecture on
# <em><strong>Fundamentals of Data Analaysis module on Higher Diploma in Science in Computing in Data Analytics at ATU</strong></em>.
#
#
# Table of content:
#
# * collatz
# * flip a coin
# * overview of the famous penguins data set
# ***

# %% [markdown]
# ## Task 1
# ***
#  > The Collatz conjecture1 is a famous unsolved problem in mathematics. The problem is to prove that if you start with any positive integer x and repeatedly apply the function f(x) below, you always get stuck in the repeating sequence 1, 4, 2, 1, 4, 2, . .

# %% [markdown]
# The Collatz conjecture, or the "3n+1 problem," is one we're still waiting to see solved. Introduced in 1937 by German mathematician Lothar Collatz, the Collatz conjecture is a seemingly straightforward question with a surprisingly elusive answer. The conjecture posits that if you repeat two simple arithmetic operations, you will eventually end up transforming every positive integer into the number one. The problem is that it has not yet been proven to be true for all integers. Maybe with some number the sequence gallops off into infinity.
#
#
# Ref: *Even the Smartest Mathematicians Can't Solve the Collatz Conjecture*, https://science.howstuffworks.com/math-concepts/collatz-conjecture.htm#:~:text=The%20conjecture%20posits%20that%20if,be%20true%20for%20all%20integers.

# %% [markdown]
# #### General setup

# %%
# Crate function named 'f' with a parameter x 
def f(x):
    sequence = [x]    # crate sequence
    while x != 1:
        # check if value x is even
        if x % 2 == 0:
            # if value x is even than divide by 2
            x = x // 2
        else:
            # if vale x is odd, multiple by 3 and add 1
            x = 3 * x + 1
        sequence.append(x)
    return sequence

# %%
# Add the starting value x2 
x2 = 16
# Store result in result number 
result_number = f(x2)
# Print result 
print (result_number)
# Out:
# [16, 8, 4, 2, 1]

# %% [markdown]
# ## Task 2
# ***
#
# > Give an overview of the famous penguins data set, explaininhe types of variables it contains. Suggest the types of variables
# that should be used to model them in Python, explaining your rationale.

# %% [markdown]
# <img src="palmer-penguins.png">

# %% [markdown]
# The Penguins dataset were collected from 2007–2009 by Dr. Kristen Gorman with the Palmer Station Long Term Ecological Research Program, part of the US Long Term Ecological Research Network[11].

# %% [markdown]
# ##### Main types of data statiscic[10]:
#
# &rarr;Categorical Data
#
# * Nominal data
#
# * Ordinal data
#
# &rarr;Numerical Data
#
# * Discrete data
#
# * Continuous data
#
# <img src="datatype.png">
#
#
#
# The Penguins dataset inclueds the following types of variables:
#
# Categorical Variables:
#
# * Species: the varibales represent the species of the penguin (Adelie, Chinstrap, Gentoo)
# * Island: the variable represent the island where the penuin was observed (Torgersen, Dream, Biscoe)
# * Sex: represent the gender of the penguin (Male or Femal)
#
#
# Numeric Variables:
#
# * Bill Length: the variable represents the length of the penguin's beak in millimeters(mm). This varibale is continuous numeric variable
# * Bill Depth: the variable represents the depth of the penguin's beak in millimeters(mm)
# * Flipper Length: represents the penguis's fin in milimiters (mm)
# * Body Mass: the variable represnets the penguin's body weight in grams (g)
#
#
# When modeling data in Python, it is important to understand the types of variables.
# The penguin dataset contains three different species of penguins: Adelie, Chinstrap, and Gentoo.
#
# Using Python, we can analyze, visualize data, and build predictive models to gain insight into the characteristics of different penguin species in the dataset.
#
# Suggested Variable Types for Modeling in Python:
#
# * Species, Island, Sex represents nominal variables. These categories have no particular order, and they contain text values. We can model them in Python using strings.
#
# * Bill Length, Bill Depth, Flipper Lengt, Body Mass represents continuous data type because they can take any numerical value, we can use <code>pandas</code> . Numerical variables that represent floating point numbers should be modeled using the float data type in Python.

# %% [markdown]
# Types of variables of the famouse penguins dataset.

# %%
# Import pandas
import pandas as pd

# Pprovide the raw file URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"

# Read the CSV file
pingwiny = pd.read_csv(url, encoding='ISO-8859-1')

# %%
# Checking data types
pingwiny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   species           1000 non-null   object
#  1   numeric_variable  1000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 15.8+ KB

# %%
# Checking top 10 observation
pingwiny.head(10)
# Out:
#      species  numeric_variable
# 0  Chinstrap         10.836907
# 1  Chinstrap         13.676297
# 2  Chinstrap         11.485050
# 3     Adelie         12.095521
# 4  Chinstrap          9.518928
# 5  Chinstrap         11.832816
# 6     Gentoo         14.724220
# 7     Gentoo         11.048413
# 8     Gentoo          4.722614
# 9     Adelie         13.290791

# %% [markdown]
# ## Task 3
#
# ***
# > For each of the variables in the penguins data set, suggest what probability distribution from the numpy random distributions list
#  is the most appropriate to model the variable.

# %% [markdown]
# Probability distribution from the numpy random distributions list is the most appropriate to model the variable.
#
# * Bill Length: Suggested Distribution: Normal Distribution (numpy.random.normal)
# * Bill Depth: Suggested Distribution: Normal Distribution (numpy.random.normal)
# * Flipper Length: Suggested Distribution: Normal Distribution (numpy.random.normal)
# * Body Mass: Suggested Distribution: Normal Distribution (numpy.random.normal)

# %%
# Importing numpy for probility distribustion 
import numpy as np

# %%
# Create frequency table for the 'species' variable
frequency_table = pingwiny['species'].value_counts()

# Display the frequency table
print(frequency_table)
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Define colors for each species
colors = {'Adelie': 'aqua', 'Gentoo': 'pink', 'Chinstrap': 'orange'}

# Plot the bar chart
plt.bar(frequency_table.index, frequency_table, color=[colors[species] for species in frequency_table.index])
# Adding labales
plt.xlabel('Species')
plt.ylabel('Count')
#Adding title
plt.title('Frequency of Penguin Species')
#Adding legend
plt.legend(['All Species'])
plt.show()

# %%
# import library 
import numpy as np

# Create probabilities
probabilities = [0.3, 0.4, 0.3]

# Generate random samples 
pingwiny_data = np.random.choice(['Adelie', 'Chinstrap', 'Gentoo'], size=1000, p=probabilities)

# Print the resulting array
print(pingwiny_data)
# Out:
# ['Adelie' 'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Adelie' 'Chinstrap'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Adelie' 'Adelie' 'Adelie' 'Gentoo' 'Chinstrap'
#  'Adelie' 'Gentoo' 'Gentoo' 'Chinstrap' 'Chinstrap' 'Adelie' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap' 'Adelie'
#  'Gentoo' 'Adelie' 'Chinstrap' 'Adelie' 'Chinstrap' 'Chinstrap'
#  'Chinstrap' 'Adelie' 'Chinstrap' 'Chinstrap' 'Gentoo' 'Adelie' 'Gentoo'
#  'Chinstrap' 'Adelie' 'Chinstrap' 'Chinstrap' 'Adelie' 'Chinstrap'
#  'Chinstrap' 'Chinstrap' 'Chinstrap' 'Chinstrap' 'Chinstrap' 'Adelie'
#  'Chinstrap' 'Adelie' 'Adelie' 'Chinstrap' 'Adelie' 'Chinstrap'
#  'Chinstrap' 'Gentoo' 'Adelie' 'Chinstrap' 'Chinstrap' 'Gentoo' 'Gentoo'
#  'Chinstrap' 'Chinstrap' 'Chinstrap' 'Chinstrap' 'Chinstrap' 'Chinstrap'
#  'Adelie' 'Gentoo' 'Gentoo' 'Adelie' 'Gentoo' 'Chinstrap' 'Chinstrap'
# ...

# %%
# import library
import seaborn as sns

# Generate random data 
penguin_data = pd.DataFrame({
    'species': np.random.choice(['Adelie', 'Chinstrap', 'Gentoo'], size=1000, p=[0.44, 0.2, 0.36]),
    'island': np.random.choice(['Torgersen', 'Biscoe', 'Dream'], size=1000, p=[0.3, 0.4, 0.3])
})

# Plot the distribution of the 'island' variable
plt.figure(figsize=(8, 5))
sns.countplot(x='island', data=penguin_data, palette='Set2')
#Adding labels
plt.xlabel('Island')
plt.ylabel('Count')
plt.title('Distribution of Penguin Species on Islands')
plt.show()

# %%
# Craete frequency table for sex
# Generate random data 
penguin_data = pd.DataFrame({
    'species': np.random.choice(['Adelie', 'Chinstrap', 'Gentoo'], size=1000, p=[0.44, 0.2, 0.36]),
    'island': np.random.choice(['Torgersen', 'Biscoe', 'Dream'], size=1000, p=[0.3, 0.4, 0.3]),
    'sex': np.random.choice(['Male', 'Female'], size=1000, p=[0.5, 0.5])
})

# Create a frequency table for 'Male' and 'Female' sexes
sex_frequency = penguin_data['sex'].value_counts() #extracts the 'sex' column from the DataFram

# Display the frequency table
print(sex_frequency)
# Out:
# Female    506
# Male      494
# Name: sex, dtype: int64

# %%
# Craete frequency bar chart for sex
# Generate random data 
penguin_data = pd.DataFrame({
    'species': np.random.choice(['Adelie', 'Chinstrap', 'Gentoo'], size=1000, p=[0.44, 0.2, 0.36]),
    'island': np.random.choice(['Torgersen', 'Biscoe', 'Dream'], size=1000, p=[0.3, 0.4, 0.3]),
    'sex': np.random.choice(['Male', 'Female'], size=1000, p=[0.5, 0.5])
})

# Plot the distribution of the 'sex' variable
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=penguin_data, palette='pastel')
#Adding labels
plt.xlabel('Sex')
plt.ylabel('Count')
#Adding title 
plt.title('Distribution of Penguin Sex')
plt.show()

# %%
# Create histahistogram of normal distributions
# Parameters for the normal distributions (mean and standard deviation)
mean_bill_length, std_dev_bill_length = 40, 5
mean_bill_depth, std_dev_bill_depth = 17, 2
mean_flipper_length, std_dev_flipper_length = 200, 20
mean_body_mass, std_dev_body_mass = 4000, 500

# Generate random samples from normal distributions
bill_length_samples = np.random.normal(mean_bill_length, std_dev_bill_length, 1000)
bill_depth_samples = np.random.normal(mean_bill_depth, std_dev_bill_depth, 1000)
flipper_length_samples = np.random.normal(mean_flipper_length, std_dev_flipper_length, 1000)
#body_mass_samples = np.random.normal(mean_body_mass, std_dev_body_mass, 1000)


#Plot histograms 
plt.figure(figsize=(14, 8))

plt.subplot(2, 2, 1)
plt.hist(bill_length_samples, bins=30, color='blue', alpha=0.7)
# Adding title 
plt.title('Bill Length')
#Adding grid 
plt.grid()

plt.subplot(2, 2, 2)
plt.hist(bill_depth_samples, bins=30, color='green', alpha=0.7)
# Adding title 
plt.title('Bill Depth')
#Adding grid 
plt.grid()

plt.subplot(2, 2, 3)
plt.hist(flipper_length_samples, bins=30, color='aqua', alpha=0.7)
# Adding title 
plt.title('Flipper Length')
#Adding grid 
plt.grid()

plt.subplot(2, 2, 4)
plt.hist(body_mass_samples, bins=30, color='pink', alpha=0.7)
# Adding title 
plt.title('Body Mass')
#Adding grid 
plt.grid()

# Show histagram
plt.show()

# %% [markdown]
# ## Task 4
# ***
# > Suppose you are flipping two coins, each with a probability p of
# giving heads. Plot the entropy of the total number of heads versus p.

# %% [markdown]
# Entropy is a scientific concept, as well as a measurable physical property that is most commonly associated with a state of disorder, randomness, or uncertainty. The term and the concept are used in diverse fields, from classical thermodynamics, where it was first recognized, to the microscopic description of nature in statistical physics, and to the principles of information theor[7].

# %% [markdown]
# #### Use the formula for information entropy[8]:
#
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>X</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mo>&#x2212;<!-- − --></mo>
#   <munder>
#     <mo>&#x2211;<!-- ∑ --></mo>
#     <mi>i</mi>
#   </munder>
#   <mi>P</mi>
#   <mo stretchy="false">(</mo>
#   <mi>X</mi>
#   <mo>=</mo>
#   <mi>i</mi>
#   <mo stretchy="false">)</mo>
#   <mi>l</mi>
#   <mi>o</mi>
#   <msub>
#     <mi>g</mi>
#     <mn>2</mn>
#   </msub>
#   <mi>P</mi>
#   <mo stretchy="false">(</mo>
#   <mi>X</mi>
#   <mo>=</mo>
#   <mi>i</mi>
#   <mo stretchy="false">)</mo>
# </math>

# %% [markdown]
# #### General setup

# %%
# Import matplot for plotting 
import matplotlib.pyplot as plt 
# Import 
import numpy as np

# %%
# function for building plot 
# X= 0 no heads
# X= 1 one head
# X= 2 both coins are heads

# X = 1 means getting exactly one head in the two coin flips


def entropy(p):
    p0 = (1 -p)**2
    p1 = 2 * p * (1 - p)
    p2 = p**2
    probabilities = [p0, p1, p2]
    #entropy = -np.sum(p * np.log2(p) if p != 0 else 0 for p in probabilities)
    entropy = -np.sum(np.fromiter((p * np.log2(p) if p != 0 else 0 for p in probabilities), dtype=float))
    return entropy

# create p value
p_value = np.linspace(0, 1, 100)

# enropy for each p 
ent = [entropy(p) for p in p_value]

# Creat plot 

plt.plot(p_value, ent, label= "Entropy" )
plt.title(" Probability of Heads for Two Coins Flips ")
plt.ylabel("Probability of Heads")
plt.xlabel("Enropy")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### The shape of the enropy function for a coin where the probability of H is p

# %% [markdown]
# # Task 5
#
# ***
# > Create an appropriate individual plot for each of the variables in
# the penguin data set.

# %%
# Import matplot 
import matplotlib.pyplot as plt
# Import seborn
import seaborn as sns
# Import pandas
import pandas as pd

# %% [markdown]
# #### Plotting for Categorical Variables

# %%
# Adding plot 
sns.set(style="whitegrid")
# Add color palette
custom_palette = ['skyblue', 'pink', 'lightgreen']
sns.countplot(x='species', data=pingwiny, palette=custom_palette)
# Add a title
plt.title('Count of Penguins by Species')
plt.show()

# %%
# Adding plot 
sns.countplot(x='sex', data=pingwiny)
# Add a title
plt.title('Count of Penguins by Sex')
plt.show()

# %%
# Add color palette
custom_palette = ['skyblue', 'pink', 'lightgreen']
# Adding plot 
sns.countplot(x='island', data=pingwiny, palette=custom_palette)
# Add a title
plt.title('Count of Penguins by Species')
plt.show()

# %% [markdown]
# #### Plotting for Numerical Variables

# %%
# Create histagram
sns.histplot(pingwiny['flipper_length_mm'], kde=True, color= "orange")
# Add a title
plt.title('Distribution of Flipper Length_mm')
plt.show()

# %%
# Create histagram
sns.histplot(pingwiny['bill_depth_mm'], kde=True, color= "cyan")
# Add a title
plt.title('Distribution of Bill Depth')
plt.show()

# %%
# Create histagram
sns.histplot(pingwiny['bill_length_mm'], kde=True, color= "magenta")
# Add a title
plt.title('Distribution of Bill Length')
plt.show()

# %% [markdown]
# ### Reference
#
# *Data type objects*, NumPy Developers  https://numpy.org/doc/stable/reference/arrays.dtypes.html
#
# *Collatz Sequence*, YouTube  https://www.youtube.com/watch?v=VuMqOd73ek8
#
# *Collatz Sequence*, Medium  https://medium.com/the-art-of-python/the-collatz-sequence-in-python-eb7e1f1b4f9e
#
# *Collatz Sequence* https://stackoverflow.com/questions/61789065/automate-the-boring-stuff-with-python-collatz-sequence
#
# *Collatz* https://science.howstuffworks.com/math-concepts/collatz-conjecture.htm#:~:text=The%20conjecture%20posits%20that%20if,be%20true%20for%20all%20integers
#
# *Probability Distributions for Discrete Random Variables* https://saylordotorg.github.io/text_introductory-statistics/s08-02-probability-distributions-for-.html
#
# *Coin Flip Probability Calculator* https://www.omnicalculator.com/statistics/coin-flip-probability
#
# *Entropy of a fair coin toss*,  Marton Trencseni https://bytepawn.com/what-is-the-entropy-of-a-fair-coin-toss.
#
# *Formula for information entropy*,  http://www.w3.org/1998/Math/MathML
#
# *Seaborn.set_style*, Michael Waskom https://seaborn.pydata.org/generated/seaborn.set_style.html
#
# *Data type Built In*,  https://builtin.com/data-science/data-types-statistics
#
# *The Penguins dataset* The Penguins dataset were collected from 2007–2009 by Dr. Kristen Gorman
#
# *Boxplot* , https://sebastiancallh.github.io/post/multi-armed-bandits-and-penguins/
#
# *Probability distribution* , https://en.wikipedia.org/wiki/Probability_distribution
#
# *Normal Distribution in Python* , https://www.datacamp.com/tutorial/probability-distributions-python
#
# *Types Of Data*: , https://www.mygreatlearning.com/blog/types-of-data/{
#
# *Matplot* ,  https://matplotlib.org/
#
# *Numpy.random.choice*, https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

# %% [markdown]
# ***
# #### End
